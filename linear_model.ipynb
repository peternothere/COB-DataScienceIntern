# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score

# %%
train_data = pd.read_csv("/train_dataset.csv")
train_data
# Out:
#       x          y  Unnamed: 2  Unnamed: 3  Unnamed: 4
# 0    24  21.549452         NaN         NaN         NaN
# 1    50  47.464463         NaN         NaN         NaN
# 2    15  17.218656         NaN         NaN         NaN
# 3    38  36.586398         NaN         NaN         NaN
# 4    87  87.288984         NaN         NaN         NaN
# ..   ..        ...         ...         ...         ...
# 694  58  58.595006         NaN         NaN         NaN
# 695  93  94.625094         NaN         NaN         NaN
# 696  82  88.603770         NaN         NaN         NaN
# 697  66  63.648685         NaN         NaN         NaN
# 698  97  94.975266         NaN         NaN         NaN
#
# [699 rows x 5 columns]

# %%
#preprocessing the training data
unnamed_columns = [col for col in train_data.columns if col.startswith("Unnamed:")]

train_data = train_data.drop(columns=unnamed_columns)
train_data
# Out:
#       x          y
# 0    24  21.549452
# 1    50  47.464463
# 2    15  17.218656
# 3    38  36.586398
# 4    87  87.288984
# ..   ..        ...
# 694  58  58.595006
# 695  93  94.625094
# 696  82  88.603770
# 697  66  63.648685
# 698  97  94.975266
#
# [699 rows x 2 columns]

# %%
x = train_data[['x']]
y = train_data['y']

# %%
#trained model
model = LinearRegression()
model.fit(x, y)
# Out:
# LinearRegression()

# %%
test_data = pd.read_csv("/test_dataset.csv")
test_data
# Out:
#         x          y  Unnamed: 2  Unnamed: 3  Unnamed: 4
# 0    77.0  79.775152         NaN         NaN         NaN
# 1    21.0  23.177279         NaN         NaN         NaN
# 2    22.0  25.609262         NaN         NaN         NaN
# 3    20.0  17.857388         NaN         NaN         NaN
# 4    36.0  41.849864         NaN         NaN         NaN
# ..    ...        ...         ...         ...         ...
# 694   NaN        NaN         NaN         NaN         NaN
# 695   NaN        NaN         NaN         NaN         NaN
# 696   NaN        NaN         NaN         NaN         NaN
# 697   NaN        NaN         NaN         NaN         NaN
# 698   NaN        NaN         NaN         NaN         NaN
#
# [699 rows x 5 columns]

# %%
#preprocessing the test data

unnamed_columns = [col for col in test_data.columns if col.startswith("Unnamed:")]

test_data = test_data.drop(columns=unnamed_columns)

test_data
# Out:
#         x          y
# 0    77.0  79.775152
# 1    21.0  23.177279
# 2    22.0  25.609262
# 3    20.0  17.857388
# 4    36.0  41.849864
# ..    ...        ...
# 694   NaN        NaN
# 695   NaN        NaN
# 696   NaN        NaN
# 697   NaN        NaN
# 698   NaN        NaN
#
# [699 rows x 2 columns]

# %%
test_data = test_data.dropna()
test_data
# Out:
#         x          y
# 0    77.0  79.775152
# 1    21.0  23.177279
# 2    22.0  25.609262
# 3    20.0  17.857388
# 4    36.0  41.849864
# ..    ...        ...
# 295  71.0  68.545888
# 296  46.0  47.334876
# 297  55.0  54.090637
# 298  62.0  63.297171
# 299  47.0  52.459467
#
# [300 rows x 2 columns]

# %%
x_test = test_data[['x']]
y_test = test_data['y']

# %%
#predicted output
y_pred = model.predict(x_test)
y_pred
# Out:
# array([76.94327594, 20.90651855, 21.90717494, 19.90586217, 35.91636428,
#        14.90258026, 61.93343021, 94.95509081, 19.90586217,  4.89601644,
#         3.89536006, 18.90520579, 95.95574719, 61.93343021, 35.91636428,
#        14.90258026, 64.93539936, 13.90192388, 86.94983976, 68.93802488,
#        88.95115252, 50.92621001, 88.95115252, 26.91045685, 96.95640358,
#        57.93080468, 78.9445887 , 20.90651855, 92.95377805, 26.91045685,
#        98.95771634, 30.91308237, 32.91439514, 79.94524508, 27.91111323,
#        46.92358448, 52.92752277, 68.93802488, 27.91111323, 32.91439514,
#        90.95246528, 70.93933765, 49.92555363, 75.94261956,  3.89536006,
#        36.91702066, 69.93868127, 67.9373685 , 39.91898981, 34.9157079 ,
#        93.95443443, 87.95049614, 51.92686639, 30.91308237, 58.93146107,
#        -0.10726546, 38.91833343, 63.93474297, 68.93802488, 56.9301483 ,
#        12.9012675 , 71.93999403, 75.94261956, 60.93277383, 81.94655785,
# ...

# %%
plt.scatter(x_test, y_test, color='blue', label='Output')
plt.plot(x_test, y_pred, color='red', linewidth=2, label='Predicted')
plt.xlabel('x')
plt.ylabel('y')
plt.title('Linear Regression')
plt.legend()
plt.show()

# %%
r2 = r2_score(y_test, y_pred)

print("R-squared (R2) Score:", r2)
# Out:
# R-squared (R2) Score: 0.9888014444327563
